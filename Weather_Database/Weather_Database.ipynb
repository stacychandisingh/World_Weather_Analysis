# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the datetime module from the datetime library.
from datetime import datetime

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
# Import the API key.
from config_new import new_weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + new_weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e57db33e70134397d80e1ee838326e7e

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | poum
# Processing Record 3 of Set 1 | kurilsk
# Processing Record 4 of Set 1 | butaritari
# Processing Record 5 of Set 1 | hammerfest
# Processing Record 6 of Set 1 | los llanos de aridane
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | oranjestad
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | kloulklubed
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | port elizabeth
# Processing Record 14 of Set 1 | hue
# Processing Record 15 of Set 1 | taoudenni
# Processing Record 16 of Set 1 | padang
# Processing Record 17 of Set 1 | half moon bay
# Processing Record 18 of Set 1 | ye
# City not found. Skipping...
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | mahebourg
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | longyearbyen
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | bluff
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | paderborn
# Processing Record 28 of Set 1 | saint-philippe
# Processing Record 29 of Set 1 | thompson
# Processing Record 30 of Set 1 | cidreira
# Processing Record 31 of Set 1 | camacha
# Processing Record 32 of Set 1 | ankang
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | khomeyn
# Processing Record 36 of Set 1 | tuktoyaktuk
# Processing Record 37 of Set 1 | clacton-on-sea
# Processing Record 38 of Set 1 | faanui
# Processing Record 39 of Set 1 | oistins
# Processing Record 40 of Set 1 | bambous virieux
# Processing Record 41 of Set 1 | atambua
# Processing Record 42 of Set 1 | guerrero negro
# Processing Record 43 of Set 1 | isangel
# Processing Record 44 of Set 1 | avarua
# Processing Record 45 of Set 1 | nikolskoye
# Processing Record 46 of Set 1 | cape town
# Processing Record 47 of Set 1 | noumea
# Processing Record 48 of Set 1 | new norfolk
# Processing Record 49 of Set 1 | iqaluit
# Processing Record 50 of Set 1 | meiganga
# Processing Record 1 of Set 2 | ewa beach
# Processing Record 2 of Set 2 | portland
# Processing Record 3 of Set 2 | aswan
# Processing Record 4 of Set 2 | izvestkovyy
# Processing Record 5 of Set 2 | bredasdorp
# Processing Record 6 of Set 2 | bengkulu
# Processing Record 7 of Set 2 | gualeguaychu
# Processing Record 8 of Set 2 | chicama
# Processing Record 9 of Set 2 | bubaque
# Processing Record 10 of Set 2 | beringovskiy
# Processing Record 11 of Set 2 | talnakh
# Processing Record 12 of Set 2 | auki
# Processing Record 13 of Set 2 | atuona
# Processing Record 14 of Set 2 | castro
# Processing Record 15 of Set 2 | nanortalik
# Processing Record 16 of Set 2 | soyo
# Processing Record 17 of Set 2 | atar
# Processing Record 18 of Set 2 | itaqui
# Processing Record 19 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 2 | bud
# Processing Record 21 of Set 2 | victoria
# Processing Record 22 of Set 2 | jiazi
# Processing Record 23 of Set 2 | margate
# Processing Record 24 of Set 2 | saint-augustin
# Processing Record 25 of Set 2 | tyret pervaya
# Processing Record 26 of Set 2 | caconda
# Processing Record 27 of Set 2 | pevek
# Processing Record 28 of Set 2 | kodiak
# Processing Record 29 of Set 2 | carnarvon
# Processing Record 30 of Set 2 | east london
# Processing Record 31 of Set 2 | pierre
# Processing Record 32 of Set 2 | manavalakurichi
# Processing Record 33 of Set 2 | herat
# Processing Record 34 of Set 2 | bethel
# Processing Record 35 of Set 2 | dikson
# Processing Record 36 of Set 2 | torbay
# Processing Record 37 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 2 | luderitz
# Processing Record 39 of Set 2 | albany
# Processing Record 40 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 2 | pocone
# Processing Record 42 of Set 2 | zhigansk
# Processing Record 43 of Set 2 | saldanha
# Processing Record 44 of Set 2 | port alfred
# Processing Record 45 of Set 2 | hobart
# Processing Record 46 of Set 2 | lebu
# Processing Record 47 of Set 2 | mount gambier
# Processing Record 48 of Set 2 | abu dhabi
# Processing Record 49 of Set 2 | kibre mengist
# Processing Record 50 of Set 2 | lagoa
# Processing Record 1 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 3 | qaanaaq
# Processing Record 3 of Set 3 | touros
# Processing Record 4 of Set 3 | arraial do cabo
# Processing Record 5 of Set 3 | hilo
# Processing Record 6 of Set 3 | elko
# Processing Record 7 of Set 3 | smirnykh
# Processing Record 8 of Set 3 | anadyr
# Processing Record 9 of Set 3 | cherskiy
# Processing Record 10 of Set 3 | lipari
# Processing Record 11 of Set 3 | barkhan
# Processing Record 12 of Set 3 | medicine hat
# Processing Record 13 of Set 3 | mehriz
# Processing Record 14 of Set 3 | saskylakh
# Processing Record 15 of Set 3 | andevoranto
# City not found. Skipping...
# Processing Record 16 of Set 3 | kirakira
# Processing Record 17 of Set 3 | pazaric
# Processing Record 18 of Set 3 | barrow
# Processing Record 19 of Set 3 | kaitangata
# Processing Record 20 of Set 3 | taiobeiras
# Processing Record 21 of Set 3 | norman wells
# Processing Record 22 of Set 3 | egvekinot
# Processing Record 23 of Set 3 | palmerston
# Processing Record 24 of Set 3 | santa rosa
# Processing Record 25 of Set 3 | russellville
# Processing Record 26 of Set 3 | coihaique
# Processing Record 27 of Set 3 | mlonggo
# Processing Record 28 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 3 | birjand
# Processing Record 30 of Set 3 | dunedin
# Processing Record 31 of Set 3 | pitimbu
# Processing Record 32 of Set 3 | duz
# City not found. Skipping...
# Processing Record 33 of Set 3 | chokurdakh
# Processing Record 34 of Set 3 | biloxi
# Processing Record 35 of Set 3 | chemal
# Processing Record 36 of Set 3 | yulara
# Processing Record 37 of Set 3 | santa marta
# Processing Record 38 of Set 3 | batagay
# Processing Record 39 of Set 3 | alofi
# Processing Record 40 of Set 3 | provideniya
# Processing Record 41 of Set 3 | kharp
# Processing Record 42 of Set 3 | baculin
# Processing Record 43 of Set 3 | careiro da varzea
# Processing Record 44 of Set 3 | oxbow
# Processing Record 45 of Set 3 | northam
# Processing Record 46 of Set 3 | pirogovo
# Processing Record 47 of Set 3 | taltal
# Processing Record 48 of Set 3 | tautira
# Processing Record 49 of Set 3 | harper
# Processing Record 50 of Set 3 | mar del plata
# Processing Record 1 of Set 4 | chuy
# Processing Record 2 of Set 4 | katobu
# Processing Record 3 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 4 | alto piquiri
# Processing Record 5 of Set 4 | sisimiut
# Processing Record 6 of Set 4 | zabol
# Processing Record 7 of Set 4 | port blair
# Processing Record 8 of Set 4 | upernavik
# Processing Record 9 of Set 4 | mogocha
# Processing Record 10 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 4 | gornopravdinsk
# Processing Record 12 of Set 4 | nerchinskiy zavod
# Processing Record 13 of Set 4 | esperance
# Processing Record 14 of Set 4 | grand gaube
# Processing Record 15 of Set 4 | kruisfontein
# Processing Record 16 of Set 4 | bardiyah
# Processing Record 17 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 4 | tres arroyos
# Processing Record 19 of Set 4 | sao jose da coroa grande
# Processing Record 20 of Set 4 | lata
# Processing Record 21 of Set 4 | meulaboh
# Processing Record 22 of Set 4 | yenagoa
# Processing Record 23 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 4 | mount pleasant
# Processing Record 25 of Set 4 | pacific grove
# Processing Record 26 of Set 4 | kambove
# Processing Record 27 of Set 4 | port lincoln
# Processing Record 28 of Set 4 | ahipara
# Processing Record 29 of Set 4 | tiksi
# Processing Record 30 of Set 4 | tartki
# City not found. Skipping...
# Processing Record 31 of Set 4 | dingle
# Processing Record 32 of Set 4 | geraldton
# Processing Record 33 of Set 4 | muzhi
# Processing Record 34 of Set 4 | shizuishan
# Processing Record 35 of Set 4 | labuhan
# Processing Record 36 of Set 4 | senador jose porfirio
# Processing Record 37 of Set 4 | ribeira grande
# Processing Record 38 of Set 4 | lexington park
# Processing Record 39 of Set 4 | yomitan
# City not found. Skipping...
# Processing Record 40 of Set 4 | te anau
# Processing Record 41 of Set 4 | fairbanks
# Processing Record 42 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 4 | karratha
# Processing Record 44 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 4 | sobolevo
# Processing Record 46 of Set 4 | yantal
# Processing Record 47 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 4 | kununurra
# Processing Record 49 of Set 4 | walvis bay
# Processing Record 50 of Set 4 | hay river
# Processing Record 1 of Set 5 | tahta
# Processing Record 2 of Set 5 | puerto pinasco
# City not found. Skipping...
# Processing Record 3 of Set 5 | sinnamary
# Processing Record 4 of Set 5 | empalme
# Processing Record 5 of Set 5 | trairi
# Processing Record 6 of Set 5 | makakilo city
# Processing Record 7 of Set 5 | vostok
# Processing Record 8 of Set 5 | ancud
# Processing Record 9 of Set 5 | oga
# Processing Record 10 of Set 5 | codrington
# Processing Record 11 of Set 5 | lompoc
# Processing Record 12 of Set 5 | leningradskiy
# Processing Record 13 of Set 5 | bourg-en-bresse
# Processing Record 14 of Set 5 | tommot
# Processing Record 15 of Set 5 | barceloneta
# Processing Record 16 of Set 5 | cabo san lucas
# Processing Record 17 of Set 5 | vao
# Processing Record 18 of Set 5 | san carlos de bariloche
# Processing Record 19 of Set 5 | puerto quijarro
# Processing Record 20 of Set 5 | havre-saint-pierre
# Processing Record 21 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 22 of Set 5 | witu
# Processing Record 23 of Set 5 | berzence
# Processing Record 24 of Set 5 | turukhansk
# Processing Record 25 of Set 5 | saint george
# Processing Record 26 of Set 5 | hithadhoo
# Processing Record 27 of Set 5 | la ronge
# Processing Record 28 of Set 5 | acapulco
# Processing Record 29 of Set 5 | mayumba
# Processing Record 30 of Set 5 | buraydah
# Processing Record 31 of Set 5 | khatanga
# Processing Record 32 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 33 of Set 5 | kavaratti
# Processing Record 34 of Set 5 | borogontsy
# Processing Record 35 of Set 5 | punta alta
# Processing Record 36 of Set 5 | clarence town
# Processing Record 37 of Set 5 | kalmunai
# Processing Record 38 of Set 5 | garissa
# Processing Record 39 of Set 5 | jiuquan
# Processing Record 40 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 5 | narsaq
# Processing Record 42 of Set 5 | vardo
# Processing Record 43 of Set 5 | beibei
# Processing Record 44 of Set 5 | jacareacanga
# Processing Record 45 of Set 5 | kimbe
# Processing Record 46 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 5 | bafoulabe
# Processing Record 48 of Set 5 | hirado
# Processing Record 49 of Set 5 | collie
# Processing Record 50 of Set 5 | ust-nera
# Processing Record 1 of Set 6 | clyde river
# Processing Record 2 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 3 of Set 6 | dali
# Processing Record 4 of Set 6 | maningrida
# Processing Record 5 of Set 6 | husavik
# Processing Record 6 of Set 6 | port victoria
# Processing Record 7 of Set 6 | dukat
# Processing Record 8 of Set 6 | gao
# Processing Record 9 of Set 6 | stephenville
# Processing Record 10 of Set 6 | buchanan
# Processing Record 11 of Set 6 | korla
# Processing Record 12 of Set 6 | hoi an
# Processing Record 13 of Set 6 | tacuarembo
# Processing Record 14 of Set 6 | emba
# Processing Record 15 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 16 of Set 6 | kavieng
# Processing Record 17 of Set 6 | askim
# Processing Record 18 of Set 6 | georgetown
# Processing Record 19 of Set 6 | minab
# Processing Record 20 of Set 6 | yerbogachen
# Processing Record 21 of Set 6 | vila velha
# Processing Record 22 of Set 6 | burnie
# Processing Record 23 of Set 6 | akdagmadeni
# Processing Record 24 of Set 6 | muros
# Processing Record 25 of Set 6 | katsuura
# Processing Record 26 of Set 6 | menzelinsk
# Processing Record 27 of Set 6 | taburi
# City not found. Skipping...
# Processing Record 28 of Set 6 | santiago
# Processing Record 29 of Set 6 | venice
# Processing Record 30 of Set 6 | abalak
# Processing Record 31 of Set 6 | kemin
# Processing Record 32 of Set 6 | avera
# Processing Record 33 of Set 6 | naujamiestis
# Processing Record 34 of Set 6 | teeli
# Processing Record 35 of Set 6 | pisco
# Processing Record 36 of Set 6 | pozo colorado
# Processing Record 37 of Set 6 | samarai
# Processing Record 38 of Set 6 | umm kaddadah
# Processing Record 39 of Set 6 | teguise
# Processing Record 40 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 6 | gravdal
# Processing Record 42 of Set 6 | senneterre
# Processing Record 43 of Set 6 | muchkapskiy
# Processing Record 44 of Set 6 | san patricio
# Processing Record 45 of Set 6 | salalah
# Processing Record 46 of Set 6 | broome
# Processing Record 47 of Set 6 | katsiveli
# City not found. Skipping...
# Processing Record 48 of Set 6 | ambulu
# Processing Record 49 of Set 6 | ostrovnoy
# Processing Record 50 of Set 6 | san angelo
# Processing Record 1 of Set 7 | ribas do rio pardo
# Processing Record 2 of Set 7 | tynda
# Processing Record 3 of Set 7 | colomi
# Processing Record 4 of Set 7 | jahrom
# City not found. Skipping...
# Processing Record 5 of Set 7 | kyshtovka
# Processing Record 6 of Set 7 | ayan
# Processing Record 7 of Set 7 | sola
# Processing Record 8 of Set 7 | hami
# Processing Record 9 of Set 7 | aklavik
# Processing Record 10 of Set 7 | college
# Processing Record 11 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 12 of Set 7 | astoria
# Processing Record 13 of Set 7 | tasiilaq
# Processing Record 14 of Set 7 | hokitika
# Processing Record 15 of Set 7 | jablah
# Processing Record 16 of Set 7 | adrar
# Processing Record 17 of Set 7 | gannan
# Processing Record 18 of Set 7 | ponta delgada
# Processing Record 19 of Set 7 | maraa
# Processing Record 20 of Set 7 | keetmanshoop
# Processing Record 21 of Set 7 | pavlivka
# Processing Record 22 of Set 7 | skalat
# Processing Record 23 of Set 7 | sorada
# Processing Record 24 of Set 7 | port hardy
# Processing Record 25 of Set 7 | dzhida
# Processing Record 26 of Set 7 | haines junction
# Processing Record 27 of Set 7 | tateyama
# Processing Record 28 of Set 7 | thinadhoo
# Processing Record 29 of Set 7 | souillac
# Processing Record 30 of Set 7 | gurgan
# City not found. Skipping...
# Processing Record 31 of Set 7 | baghdad
# Processing Record 32 of Set 7 | verkhoyansk
# Processing Record 33 of Set 7 | petric
# City not found. Skipping...
# Processing Record 34 of Set 7 | vazhiny
# Processing Record 35 of Set 7 | lufilufi
# Processing Record 36 of Set 7 | mundgod
# Processing Record 37 of Set 7 | yar-sale
# Processing Record 38 of Set 7 | daitari
# Processing Record 39 of Set 7 | svetlyy
# Processing Record 40 of Set 7 | landeck
# Processing Record 41 of Set 7 | kabare
# Processing Record 42 of Set 7 | jinxiang
# Processing Record 43 of Set 7 | skjervoy
# Processing Record 44 of Set 7 | komyshnya
# Processing Record 45 of Set 7 | ugoofaaru
# Processing Record 46 of Set 7 | tuburan
# Processing Record 47 of Set 7 | ponsacco
# Processing Record 48 of Set 7 | hofn
# Processing Record 49 of Set 7 | kudahuvadhoo
# Processing Record 50 of Set 7 | hualmay
# Processing Record 1 of Set 8 | bayabas
# Processing Record 2 of Set 8 | susanville
# Processing Record 3 of Set 8 | bobrovka
# Processing Record 4 of Set 8 | rio grande
# Processing Record 5 of Set 8 | omboue
# Processing Record 6 of Set 8 | aleksandrov gay
# Processing Record 7 of Set 8 | constitucion
# Processing Record 8 of Set 8 | malakal
# Processing Record 9 of Set 8 | baltati
# Processing Record 10 of Set 8 | bathsheba
# Processing Record 11 of Set 8 | bahia blanca
# Processing Record 12 of Set 8 | benguela
# Processing Record 13 of Set 8 | airai
# Processing Record 14 of Set 8 | smithers
# Processing Record 15 of Set 8 | ambilobe
# Processing Record 16 of Set 8 | nuuk
# Processing Record 17 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 8 | monroe
# Processing Record 19 of Set 8 | aitape
# Processing Record 20 of Set 8 | raudeberg
# Processing Record 21 of Set 8 | ponta do sol
# Processing Record 22 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 8 | koshurnikovo
# Processing Record 24 of Set 8 | sabana de torres
# Processing Record 25 of Set 8 | xichang
# Processing Record 26 of Set 8 | marsh harbour
# Processing Record 27 of Set 8 | storslett
# Processing Record 28 of Set 8 | eskisehir
# Processing Record 29 of Set 8 | batsfjord
# Processing Record 30 of Set 8 | pasighat
# Processing Record 31 of Set 8 | gumushane
# City not found. Skipping...
# Processing Record 32 of Set 8 | acari
# Processing Record 33 of Set 8 | klaksvik
# Processing Record 34 of Set 8 | blacksburg
# Processing Record 35 of Set 8 | tabou
# Processing Record 36 of Set 8 | khovu-aksy
# Processing Record 37 of Set 8 | lalomanu
# City not found. Skipping...
# Processing Record 38 of Set 8 | babu
# Processing Record 39 of Set 8 | miri
# Processing Record 40 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 8 | tual
# Processing Record 42 of Set 8 | tanout
# Processing Record 43 of Set 8 | fort wellington
# Processing Record 44 of Set 8 | huambo
# Processing Record 45 of Set 8 | takoradi
# Processing Record 46 of Set 8 | manacor
# Processing Record 47 of Set 8 | esmeraldas
# Processing Record 48 of Set 8 | rio gallegos
# Processing Record 49 of Set 8 | tabriz
# Processing Record 50 of Set 8 | chapais
# Processing Record 1 of Set 9 | alexandria
# Processing Record 2 of Set 9 | warrington
# Processing Record 3 of Set 9 | hongjiang
# Processing Record 4 of Set 9 | severo-kurilsk
# Processing Record 5 of Set 9 | kabalo
# Processing Record 6 of Set 9 | tuatapere
# Processing Record 7 of Set 9 | awassa
# Processing Record 8 of Set 9 | hasaki
# Processing Record 9 of Set 9 | ust-maya
# Processing Record 10 of Set 9 | kathmandu
# Processing Record 11 of Set 9 | iranshahr
# Processing Record 12 of Set 9 | cam pha
# City not found. Skipping...
# Processing Record 13 of Set 9 | koluszki
# Processing Record 14 of Set 9 | dunmore town
# Processing Record 15 of Set 9 | bontang
# Processing Record 16 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 17 of Set 9 | bugiri
# Processing Record 18 of Set 9 | faya
# Processing Record 19 of Set 9 | malyye derbety
# Processing Record 20 of Set 9 | zafra
# Processing Record 21 of Set 9 | paz de ariporo
# City not found. Skipping...
# Processing Record 22 of Set 9 | riyadh
# Processing Record 23 of Set 9 | sioux lookout
# Processing Record 24 of Set 9 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 25 of Set 9 | lander
# Processing Record 26 of Set 9 | kandrian
# Processing Record 27 of Set 9 | nemuro
# Processing Record 28 of Set 9 | aljezur
# Processing Record 29 of Set 9 | dubbo
# Processing Record 30 of Set 9 | okha
# Processing Record 31 of Set 9 | klyuchi
# Processing Record 32 of Set 9 | beloha
# Processing Record 33 of Set 9 | macapa
# Processing Record 34 of Set 9 | piacabucu
# Processing Record 35 of Set 9 | yeppoon
# Processing Record 36 of Set 9 | mandera
# Processing Record 37 of Set 9 | reyes
# Processing Record 38 of Set 9 | tambacounda
# Processing Record 39 of Set 9 | moose factory
# Processing Record 40 of Set 9 | quatre cocos
# Processing Record 41 of Set 9 | ust-kulom
# Processing Record 42 of Set 9 | siwan
# Processing Record 43 of Set 9 | bad kissingen
# Processing Record 44 of Set 9 | bosaso
# Processing Record 45 of Set 9 | valparaiso
# Processing Record 46 of Set 9 | vestmannaeyjar
# Processing Record 47 of Set 9 | winneba
# Processing Record 48 of Set 9 | bocicoiu mare
# Processing Record 49 of Set 9 | anahuac
# Processing Record 50 of Set 9 | vagur
# Processing Record 1 of Set 10 | coahuayana
# Processing Record 2 of Set 10 | newcastle
# Processing Record 3 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 4 of Set 10 | lavrentiya
# Processing Record 5 of Set 10 | caravelas
# Processing Record 6 of Set 10 | axim
# Processing Record 7 of Set 10 | bambanglipuro
# Processing Record 8 of Set 10 | gimli
# Processing Record 9 of Set 10 | hambantota
# Processing Record 10 of Set 10 | sao borja
# Processing Record 11 of Set 10 | dongsheng
# Processing Record 12 of Set 10 | westport
# Processing Record 13 of Set 10 | general roca
# Processing Record 14 of Set 10 | saint-pierre
# Processing Record 15 of Set 10 | chala
# Processing Record 16 of Set 10 | el faiyum
# City not found. Skipping...
# Processing Record 17 of Set 10 | diamantino
# Processing Record 18 of Set 10 | labuan
# Processing Record 19 of Set 10 | cerro de pasco
# Processing Record 20 of Set 10 | naze
# Processing Record 21 of Set 10 | kodinsk
# Processing Record 22 of Set 10 | namibe
# Processing Record 23 of Set 10 | chengde
# Processing Record 24 of Set 10 | saint paul
# Processing Record 25 of Set 10 | ler
# Processing Record 26 of Set 10 | chilca
# Processing Record 27 of Set 10 | fortuna
# Processing Record 28 of Set 10 | nortelandia
# Processing Record 29 of Set 10 | olafsvik
# Processing Record 30 of Set 10 | champerico
# Processing Record 31 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 10 | vangaindrano
# Processing Record 33 of Set 10 | iracoubo
# Processing Record 34 of Set 10 | saint-francois
# Processing Record 35 of Set 10 | grindavik
# Processing Record 36 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 37 of Set 10 | yunjinghong
# City not found. Skipping...
# Processing Record 38 of Set 10 | whitianga
# Processing Record 39 of Set 10 | ukiah
# Processing Record 40 of Set 10 | constantine
# Processing Record 41 of Set 10 | warrnambool
# Processing Record 42 of Set 10 | bonfim
# Processing Record 43 of Set 10 | felidhoo
# City not found. Skipping...
# Processing Record 44 of Set 10 | yining
# Processing Record 45 of Set 10 | hovd
# Processing Record 46 of Set 10 | afmadu
# City not found. Skipping...
# Processing Record 47 of Set 10 | bandarbeyla
# Processing Record 48 of Set 10 | dingzhou
# Processing Record 49 of Set 10 | pombas
# Processing Record 50 of Set 10 | paita
# Processing Record 1 of Set 11 | tshane
# Processing Record 2 of Set 11 | havre
# Processing Record 3 of Set 11 | sunamganj
# City not found. Skipping...
# Processing Record 4 of Set 11 | vetapalem
# Processing Record 5 of Set 11 | linhares
# Processing Record 6 of Set 11 | kasongo-lunda
# Processing Record 7 of Set 11 | henties bay
# Processing Record 8 of Set 11 | dubai
# Processing Record 9 of Set 11 | namatanai
# Processing Record 10 of Set 11 | cayenne
# Processing Record 11 of Set 11 | martinsburg
# Processing Record 12 of Set 11 | mineros
# Processing Record 13 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 14 of Set 11 | pangnirtung
# Processing Record 15 of Set 11 | octeville
# Processing Record 16 of Set 11 | kabo
# Processing Record 17 of Set 11 | kiruna
# Processing Record 18 of Set 11 | izmit
# Processing Record 19 of Set 11 | dandong
# Processing Record 20 of Set 11 | taga
# Processing Record 21 of Set 11 | eureka
# Processing Record 22 of Set 11 | miles city
# Processing Record 23 of Set 11 | colares
# Processing Record 24 of Set 11 | qaqortoq
# Processing Record 25 of Set 11 | potiskum
# Processing Record 26 of Set 11 | ihosy
# Processing Record 27 of Set 11 | amapa
# Processing Record 28 of Set 11 | santa cruz de la palma
# Processing Record 29 of Set 11 | vila
# Processing Record 30 of Set 11 | amahai
# Processing Record 31 of Set 11 | neryungri
# Processing Record 32 of Set 11 | nizhniy kuranakh
# Processing Record 33 of Set 11 | batemans bay
# Processing Record 34 of Set 11 | san quintin
# Processing Record 35 of Set 11 | luxeuil-les-bains
# Processing Record 36 of Set 11 | maymyo
# Processing Record 37 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 38 of Set 11 | dwarka
# Processing Record 39 of Set 11 | antropovo
# Processing Record 40 of Set 11 | mizdah
# Processing Record 41 of Set 11 | bay roberts
# Processing Record 42 of Set 11 | perigueux
# Processing Record 43 of Set 11 | deputatskiy
# Processing Record 44 of Set 11 | nabire
# Processing Record 45 of Set 11 | evensk
# Processing Record 46 of Set 11 | townsville
# Processing Record 47 of Set 11 | vilani
# Processing Record 48 of Set 11 | caluquembe
# Processing Record 49 of Set 11 | tabialan
# City not found. Skipping...
# Processing Record 50 of Set 11 | komsomolskiy
# Processing Record 1 of Set 12 | itarema
# Processing Record 2 of Set 12 | sao joao da barra
# Processing Record 3 of Set 12 | bom jesus
# Processing Record 4 of Set 12 | calw
# Processing Record 5 of Set 12 | zaysan
# Processing Record 6 of Set 12 | karpogory
# Processing Record 7 of Set 12 | rawlins
# Processing Record 8 of Set 12 | cabedelo
# Processing Record 9 of Set 12 | bastrop
# Processing Record 10 of Set 12 | sorong
# Processing Record 11 of Set 12 | tongling
# Processing Record 12 of Set 12 | santa maria
# Processing Record 13 of Set 12 | bereda
# Processing Record 14 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 15 of Set 12 | kuytun
# Processing Record 16 of Set 12 | saint-gaudens
# Processing Record 17 of Set 12 | mozarlandia
# Processing Record 18 of Set 12 | vila franca do campo
# Processing Record 19 of Set 12 | orgovany
# Processing Record 20 of Set 12 | boguchany
# Processing Record 21 of Set 12 | basco
# Processing Record 22 of Set 12 | nome
# Processing Record 23 of Set 12 | mwinilunga
# Processing Record 24 of Set 12 | misratah
# Processing Record 25 of Set 12 | moron
# Processing Record 26 of Set 12 | pacasmayo
# Processing Record 27 of Set 12 | ajdabiya
# Processing Record 28 of Set 12 | calamar
# Processing Record 29 of Set 12 | altay
# Processing Record 30 of Set 12 | crestline
# Processing Record 31 of Set 12 | mareeba
# Processing Record 32 of Set 12 | lindi
# Processing Record 33 of Set 12 | jeremie
# Processing Record 34 of Set 12 | bulihan
# Processing Record 35 of Set 12 | sinop
# Processing Record 36 of Set 12 | mayskiy
# Processing Record 37 of Set 12 | saa
# Processing Record 38 of Set 12 | jintur
# Processing Record 39 of Set 12 | kungurtug
# Processing Record 40 of Set 12 | batticaloa
# Processing Record 41 of Set 12 | bowen
# Processing Record 42 of Set 12 | sur
# Processing Record 43 of Set 12 | mundi
# Processing Record 44 of Set 12 | stawell
# Processing Record 45 of Set 12 | sabang
# Processing Record 46 of Set 12 | nicoya
# Processing Record 47 of Set 12 | the valley
# Processing Record 48 of Set 12 | lazaro cardenas
# Processing Record 49 of Set 12 | wuwei
# Processing Record 50 of Set 12 | lahat
# Processing Record 1 of Set 13 | jiroft
# City not found. Skipping...
# Processing Record 2 of Set 13 | qidong
# Processing Record 3 of Set 13 | fuerte olimpo
# Processing Record 4 of Set 13 | arona
# Processing Record 5 of Set 13 | derzhavinsk
# Processing Record 6 of Set 13 | kalmar
# Processing Record 7 of Set 13 | farmington
# Processing Record 8 of Set 13 | huanuco
# Processing Record 9 of Set 13 | ilulissat
# Processing Record 10 of Set 13 | saint-louis
# Processing Record 11 of Set 13 | santa helena de goias
# Processing Record 12 of Set 13 | sao filipe
# Processing Record 13 of Set 13 | trincomalee
# Processing Record 14 of Set 13 | sundargarh
# Processing Record 15 of Set 13 | lewistown
# Processing Record 16 of Set 13 | chancay
# Processing Record 17 of Set 13 | numan
# Processing Record 18 of Set 13 | abapo
# Processing Record 19 of Set 13 | babanka
# Processing Record 20 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 21 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 13 | ginda
# Processing Record 23 of Set 13 | praia
# Processing Record 24 of Set 13 | wucheng
# Processing Record 25 of Set 13 | baykit
# Processing Record 26 of Set 13 | neiafu
# Processing Record 27 of Set 13 | kano
# Processing Record 28 of Set 13 | bhunya
# Processing Record 29 of Set 13 | caucaia
# Processing Record 30 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 31 of Set 13 | kichera
# Processing Record 32 of Set 13 | taywarah
# Processing Record 33 of Set 13 | kysyl-syr
# Processing Record 34 of Set 13 | kayasula
# Processing Record 35 of Set 13 | heide
# Processing Record 36 of Set 13 | krasnoselkup
# Processing Record 37 of Set 13 | richards bay
# Processing Record 38 of Set 13 | fochville
# Processing Record 39 of Set 13 | nizhneivkino
# Processing Record 40 of Set 13 | cay
# Processing Record 41 of Set 13 | xam nua
# Processing Record 42 of Set 13 | hervey bay
# Processing Record 43 of Set 13 | mombaca
# Processing Record 44 of Set 13 | talara
# Processing Record 45 of Set 13 | shirgaon
# Processing Record 46 of Set 13 | ulladulla
# Processing Record 47 of Set 13 | carutapera
# Processing Record 48 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 49 of Set 13 | high level
# Processing Record 50 of Set 13 | inuvik
# Processing Record 1 of Set 14 | santa isabel do rio negro
# Processing Record 2 of Set 14 | panama city
# Processing Record 3 of Set 14 | ennepetal
# Processing Record 4 of Set 14 | srednekolymsk
# Processing Record 5 of Set 14 | chimbote
# Processing Record 6 of Set 14 | corowa
# Processing Record 7 of Set 14 | rusetu
# Processing Record 8 of Set 14 | mansa
# Processing Record 9 of Set 14 | zhigalovo
# Processing Record 10 of Set 14 | bayburt
# Processing Record 11 of Set 14 | leshan
# Processing Record 12 of Set 14 | mayo
# Processing Record 13 of Set 14 | tecoanapa
# Processing Record 14 of Set 14 | trelew
# Processing Record 15 of Set 14 | lasa
# Processing Record 16 of Set 14 | nyrob
# Processing Record 17 of Set 14 | aksu
# Processing Record 18 of Set 14 | ust-ishim
# Processing Record 19 of Set 14 | usogorsk
# Processing Record 20 of Set 14 | ishinomaki
# Processing Record 21 of Set 14 | myre
# Processing Record 22 of Set 14 | kawalu
# Processing Record 23 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 24 of Set 14 | omsukchan
# Processing Record 25 of Set 14 | great falls
# Processing Record 26 of Set 14 | aranos
# Processing Record 27 of Set 14 | manbij
# Processing Record 28 of Set 14 | homer
# Processing Record 29 of Set 14 | rochegda
# Processing Record 30 of Set 14 | dien bien
# City not found. Skipping...
# Processing Record 31 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 33 of Set 14 | doka
# Processing Record 34 of Set 14 | comodoro rivadavia
# Processing Record 35 of Set 14 | healdsburg
# Processing Record 36 of Set 14 | port hedland
# Processing Record 37 of Set 14 | tessalit
# Processing Record 38 of Set 14 | papara
# Processing Record 39 of Set 14 | maroantsetra
# Processing Record 40 of Set 14 | loandjili
# Processing Record 41 of Set 14 | fukue
# Processing Record 42 of Set 14 | belorechensk
# Processing Record 43 of Set 14 | seoul
# Processing Record 44 of Set 14 | formosa
# Processing Record 45 of Set 14 | dalby
# Processing Record 46 of Set 14 | tieli
# Processing Record 47 of Set 14 | mehamn
# Processing Record 48 of Set 14 | wanning
# Processing Record 49 of Set 14 | saint-georges
# Processing Record 50 of Set 14 | kieta
# Processing Record 1 of Set 15 | nola
# Processing Record 2 of Set 15 | paonta sahib
# Processing Record 3 of Set 15 | sassandra
# Processing Record 4 of Set 15 | bauchi
# Processing Record 5 of Set 15 | shenjiamen
# Processing Record 6 of Set 15 | ndele
# Processing Record 7 of Set 15 | sitka
# Processing Record 8 of Set 15 | ust-tsilma
# Processing Record 9 of Set 15 | ngorongoro
# Processing Record 10 of Set 15 | erzin
# Processing Record 11 of Set 15 | pauna
# Processing Record 12 of Set 15 | villefranche-de-rouergue
# Processing Record 13 of Set 15 | catuday
# Processing Record 14 of Set 15 | port macquarie
# Processing Record 15 of Set 15 | sangar
# Processing Record 16 of Set 15 | crestview
# Processing Record 17 of Set 15 | san lorenzo
# Processing Record 18 of Set 15 | hare bay
# Processing Record 19 of Set 15 | rafaela
# Processing Record 20 of Set 15 | havelock
# Processing Record 21 of Set 15 | tias
# Processing Record 22 of Set 15 | rocha
# Processing Record 23 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 15 | bo
# City not found. Skipping...
# Processing Record 25 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 26 of Set 15 | eresos
# Processing Record 27 of Set 15 | santa cruz
# Processing Record 28 of Set 15 | zell am see
# Processing Record 29 of Set 15 | sosua
# Processing Record 30 of Set 15 | sambava
# Processing Record 31 of Set 15 | ulenje
# Processing Record 32 of Set 15 | howard springs
# Processing Record 33 of Set 15 | grande prairie
# Processing Record 34 of Set 15 | boma
# Processing Record 35 of Set 15 | alice springs
# Processing Record 36 of Set 15 | holme
# Processing Record 37 of Set 15 | sechura
# Processing Record 38 of Set 15 | tyukhtet
# Processing Record 39 of Set 15 | wainwright
# Processing Record 40 of Set 15 | aban
# Processing Record 41 of Set 15 | kulhudhuffushi
# Processing Record 42 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 43 of Set 15 | bengkalis
# City not found. Skipping...
# Processing Record 44 of Set 15 | halifax
# Processing Record 45 of Set 15 | marsaxlokk
# Processing Record 46 of Set 15 | zlitan
# Processing Record 47 of Set 15 | praia da vitoria
# Processing Record 48 of Set 15 | doha
# Processing Record 49 of Set 15 | poya
# Processing Record 50 of Set 15 | paveh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 684

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.tail(10)
# Out:
#                  City    Lat     Lng  Max Temp          Current Description  \
# 674        Wainwright  52.84 -110.86     37.40                    clear sky
# 675              Aban  56.67   96.06     16.48                    clear sky
# 676    Kulhudhuffushi   6.62   73.07     82.51                   few clouds
# 677           Halifax  44.65  -63.57     44.01                    clear sky
# 678        Marsaxlokk  35.84   14.54     64.99                    clear sky
# 679            Zlitan  32.47   14.57     69.69                   few clouds
# 680  Praia Da Vitoria  38.73  -27.07     71.60  light intensity shower rain
# 681              Doha  25.29   51.53     80.60                    clear sky
# 682              Poya -21.35  165.15     76.59                    clear sky
# 683             Paveh  35.04   46.36     43.02             scattered clouds
#
#      Humidity  Cloudiness  Wind Speed Country
# 674        74           3        6.93      CA
# 675        88           0        3.96      RU
# 676        72          21        7.94      MV
# 677        38           0        5.82      CA
# 678        88           0        4.70      MT
# 679        63          19        8.39      LY
# 680        88          40       13.73      PT
# 681        74           0        3.36      QA
# 682        69           1        7.11      NC
# 683        61          30        1.32      IR

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                     City Country    Lat     Lng  Max Temp  Humidity  \
# 0               Hermanus      ZA -34.42   19.23     57.00        77
# 1                   Poum      NC -20.23  164.02     77.90        78
# 2                Kurilsk      RU  45.23  147.88     46.15        71
# 3             Butaritari      KI   3.07  172.79     81.25        75
# 4             Hammerfest      NO  70.66   23.68     39.20        80
# 5  Los Llanos De Aridane      ES  28.66  -17.92     77.00        33
# 6                Rikitea      PF -23.12 -134.97     75.24        69
# 7                  Kapaa      US  22.08 -159.32     82.00        78
# 8             Oranjestad      AW  12.52  -70.03     84.20        79
# 9                Mataura      NZ -46.19  168.86     55.99        70
#
#    Cloudiness  Wind Speed Current Description
# 0           0        5.01           clear sky
# 1          41       22.79    scattered clouds
# 2          84        7.25       broken clouds
# 3         100       15.48     overcast clouds
# 4          54       16.11       broken clouds
# 5           0        9.17           clear sky
# 6           0        6.87           clear sky
# 7           1        6.87           clear sky
# 8          20       13.87          few clouds
# 9          29        7.00    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
